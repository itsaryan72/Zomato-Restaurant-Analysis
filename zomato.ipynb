# %%
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("zomato.csv", encoding="latin1")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
print(df.isnull().sum())
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
missing_cuisines = df[df['Cuisines'].isnull()]
print(missing_cuisines)
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 84        17284105                   Cookie Shoppe           216
# 87        17284211  Pearly's Famous Country Cookng           216
# 94        17284158               Jimmie's Hot Dogs           216
# 297       17374552                  Corkscrew Cafe           216
# 328       17501439                        Dovetail           216
# 346       17606621            HI Lite Bar & Lounge           216
# 368       17059060                       Hillstone           216
# 418       17142698                Leonard's Bakery           216
# 455       17616465        Tybee Island Social Club           216
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
print(df.head())
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df[df['Cuisines'].isnull()]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 84        17284105                   Cookie Shoppe           216
# 87        17284211  Pearly's Famous Country Cookng           216
# 94        17284158               Jimmie's Hot Dogs           216
# 297       17374552                  Corkscrew Cafe           216
# 328       17501439                        Dovetail           216
# 346       17606621            HI Lite Bar & Lounge           216
# 368       17059060                       Hillstone           216
# 418       17142698                Leonard's Bakery           216
# 455       17616465        Tybee Island Social Club           216
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
df['Cuisines'].value_counts().head(20)
# Out:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Pizza, Fast Food                  131
# Chinese, Fast Food                118
# Mithai, Street Food               116
# South Indian                      112
# Bakery, Fast Food                 108
# Chinese, North Indian             105
# Mughlai                           103
# Ice Cream, Desserts                83
# Ice Cream                          74
# North Indian, Fast Food            74
# Name: count, dtype: int64

# %%
df.at[17284105, 'Cuisines'] = "Bakery"

# %%
df[df['Cuisines'].isnull()]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 84      17284105.0                   Cookie Shoppe         216.0
# 87      17284211.0  Pearly's Famous Country Cookng         216.0
# 94      17284158.0               Jimmie's Hot Dogs         216.0
# 297     17374552.0                  Corkscrew Cafe         216.0
# 328     17501439.0                        Dovetail         216.0
# 346     17606621.0            HI Lite Bar & Lounge         216.0
# 368     17059060.0                       Hillstone         216.0
# 418     17142698.0                Leonard's Bakery         216.0
# 455     17616465.0        Tybee Island Social Club         216.0
#
#                City                                          Address  \
# 84           Albany               115 N Jackson St, Albany, GA 31701
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# ...

# %%
df.loc[df['Restaurant ID'] == 17284105, 'Cuisines'] = 'Bakery'

# %%
print(df['Restaurant ID'] == 17284105)
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 9547        False
# 9548        False
# 9549        False
# 9550        False
# 17284105    False
# Name: Restaurant ID, Length: 9552, dtype: bool

# %%
df.loc[df['Restaurant ID'] == 17284105, ['Restaurant Name', 'Cuisines']]
# Out:
#    Restaurant Name Cuisines
# 84   Cookie Shoppe   Bakery

# %%
df.loc[df['Restaurant ID'] == 17284105, ['Restaurant ID','Restaurant Name','City','Locality','Cuisines']]
# Out:
#     Restaurant ID Restaurant Name    City Locality Cuisines
# 84     17284105.0   Cookie Shoppe  Albany   Albany   Bakery

# %%
df.loc[df['Cuisines'].isnull()]
# Out:
#      Restaurant ID                 Restaurant Name  Country Code  \
# 87      17284211.0  Pearly's Famous Country Cookng         216.0
# 94      17284158.0               Jimmie's Hot Dogs         216.0
# 297     17374552.0                  Corkscrew Cafe         216.0
# 328     17501439.0                        Dovetail         216.0
# 346     17606621.0            HI Lite Bar & Lounge         216.0
# 368     17059060.0                       Hillstone         216.0
# 418     17142698.0                Leonard's Bakery         216.0
# 455     17616465.0        Tybee Island Social Club         216.0
#
#                City                                          Address  \
# 87           Albany             814 N Slappey Blvd, Albany, GA 31701
# 94           Albany               204 S Jackson St, Albany, GA 31701
# 297     Gainesville                51 W Main St, Dahlonega, GA 30533
# 328           Macon                   543 Cherry St, Macon, GA 31201
# ...

# %%
updates = {
    17284211.0: "Italian",
    17284158.0: "Mexican",
    17374552.0: "Fast Food",
    17501439.0: "Mexican",
    17606621.0: "Chinese",
    17059060.0: "Japanese",
    17142698.0: "Bakery",
    17616465.0: "Thai"
}

for rid, cuisine in updates.items():
    df.loc[df['Restaurant ID'] == rid, 'Cuisines'] = cuisine

# %%
df.loc[df['Restaurant ID'].isin(updates.keys()), ['Restaurant ID','Cuisines']]
# Out:
#      Restaurant ID   Cuisines
# 87      17284211.0    Italian
# 94      17284158.0    Mexican
# 297     17374552.0  Fast Food
# 328     17501439.0    Mexican
# 346     17606621.0    Chinese
# 368     17059060.0   Japanese
# 418     17142698.0     Bakery
# 455     17616465.0       Thai

# %%
print(df.isnull().sum())
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.drop(index=17284105, inplace=True)

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0      6317637.0        Le Petit Souffle         162.0       Makati City
# 1      6304287.0        Izakaya Kikufuji         162.0       Makati City
# 2      6300002.0  Heat - Edsa Shangri-La         162.0  Mandaluyong City
# 3      6318506.0                    Ooma         162.0  Mandaluyong City
# 4      6314302.0             Sambo Kojin         162.0  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df[df['Has Table booking'] == 'YES']
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['Longitude'] = df['Longitude'].round(2)
df['Latitude'] = df['Latitude'].round(2)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0      6317637.0        Le Petit Souffle         162.0       Makati City
# 1      6304287.0        Izakaya Kikufuji         162.0       Makati City
# 2      6300002.0  Heat - Edsa Shangri-La         162.0  Mandaluyong City
# 3      6318506.0                    Ooma         162.0  Mandaluyong City
# 4      6314302.0             Sambo Kojin         162.0  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['Votes'] = df['Votes'].astype(int)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0      6317637.0        Le Petit Souffle         162.0       Makati City
# 1      6304287.0        Izakaya Kikufuji         162.0       Makati City
# 2      6300002.0  Heat - Edsa Shangri-La         162.0  Mandaluyong City
# 3      6318506.0                    Ooma         162.0  Mandaluyong City
# 4      6314302.0             Sambo Kojin         162.0  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['Price range'] = df['Price range'].astype(int)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0      6317637.0        Le Petit Souffle         162.0       Makati City
# 1      6304287.0        Izakaya Kikufuji         162.0       Makati City
# 2      6300002.0  Heat - Edsa Shangri-La         162.0  Mandaluyong City
# 3      6318506.0                    Ooma         162.0  Mandaluyong City
# 4      6314302.0             Sambo Kojin         162.0  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df[['Restaurant ID','Country Code']] = df[['Restaurant ID','Country Code']].astype(int)

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126513    25.854405
# std     8.791521e+06     56.750546    41.467071    11.007932
# min     5.300000e+01      1.000000  -157.950000   -41.330000
# 25%     3.019625e+05      1.000000    77.080000    28.480000
# 50%     6.004089e+06      1.000000    77.190000    28.570000
# 75%     1.835229e+07      1.000000    77.280000    28.640000
# max     1.850065e+07    216.000000   174.830000    55.980000
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df['City'].value_counts()
df['Cuisines'].value_counts().head(10)
# Out:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           355
# Fast Food                         355
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            220
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")

#1. Bar Chart for Top 10 Cities by Restaurant Count
plt.figure(figsize=(12,6))
top_cities = df['City'].value_counts().head(10)
sns.barplot(x=top_cities, y=top_cities.index, color='skyblue')
plt.title('Top 10 Cities by Number of Restaurants')
plt.xlabel('Number of Restaurants')
plt.ylabel('City')
plt.show()

# %%
#2.Histogram: Aggregate Rating Distribution
plt.figure(figsize=(10,6))
sns.histplot(df['Aggregate rating'], bins=20, kde=True, color='green')
plt.title('Distribute of Aggregate Ratings')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.show()

# %%
#3. Box Plot: Price Range vs Aggregate Rating
plt.figure(figsize=(10,6))
sns.boxplot(x="Price range", y="Aggregate rating", data=df, color="orange")
plt.title('Price Range cs Aggregate Rating')
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.show()

# %%
#4. Bar Chart: Top 10 Most Popular Cuisines
plt.figure(figsize=(12,6))
top_cuisines = df['Cuisines'].value_counts().head(10)
sns.barplot(x=top_cuisines.values, y=top_cuisines.index, color="lightcoral")
plt.title('Top 10 Most Popular Cuisines')
plt.xlabel('Number of Restaurants')
plt.ylabel('Cuisine')
plt.show()

# %%
#5. Scatter Plot: Restaurant Locations
plt.figure(figsize=(12,6))
sns.scatterplot(x='Longitude', y='Latitude', data=df, hue='City', legend=False, alpha=0.9)
plt.title('Geographic Distribution of Restaurants')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
#6. Heatmap: Correlation Matrix
plt.figure(figsize=(12,6))
corr = df[['Aggregate rating', 'Votes', 'Average Cost for two', 'Price range']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Example: Mean rating by Cuisines
df.groupby("Cuisines")["Aggregate rating"].mean().sort_values(ascending=False).head(10)
# Out:
# Cuisines
# Italian, Deli               4.9
# Hawaiian, Seafood           4.9
# American, Sandwich, Tea     4.9
# Continental, Indian         4.9
# European, Asian, Indian     4.9
# European, Contemporary      4.9
# European, German            4.9
# BBQ, Breakfast, Southern    4.9
# American, Coffee and Tea    4.9
# Sunda, Indonesian           4.9
# Name: Aggregate rating, dtype: float64
